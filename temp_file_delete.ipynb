# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\XKK\\Downloads\\GS.csv')

# %%
plt.scatter(df.Longitude,df.Latitude)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

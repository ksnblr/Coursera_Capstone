# %%
import pandas as pd

# %%
df =pd.read_csv('bostoncrime.csv')
df.district.value_counts()
# Out:
# B2     57619
# C11    49187
# D4     47757
# B3     41425
# A1     41306
# C6     26297
# D14    23071
# E13    20040
# E18    20025
# E5     15499
# A7     14936
# A15     7508
# Name: district, dtype: int64

# %%
district_name = {'A1':'Downtown','A15':'Charlestown','A7':'East Boston','B2':'Roxbury','B3':'Mattappan','C6':'South Boston','C11':'Dorchester','D4':'South End','D14':'Brighton','E5':'West Roxbury','E13':'Jamaica Plain','E18':'Hyde Park'}

# %%
df['District_Name'] = df['district'].map(district_name)

# %%
df.shooting.value_counts()
# Out:
# Y    1479
# Name: shooting, dtype: int64

# %%
df = df.fillna('N')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366638 entries, 0 to 366637
# Data columns (total 18 columns):
# incident_number        366638 non-null object
# offense_code           366638 non-null int64
# offense_code_group     366638 non-null object
# offense_description    366638 non-null object
# district               366638 non-null object
# reporting_area         366638 non-null object
# shooting               366638 non-null object
# occurred_on_date       366638 non-null object
# year                   366638 non-null int64
# month                  366638 non-null int64
# day_of_week            366638 non-null object
# hour                   366638 non-null int64
# ucr_part               366638 non-null object
# street                 366638 non-null object
# lat                    366638 non-null object
# long                   366638 non-null object
# location               366638 non-null object
# District_Name          366638 non-null object
# ...

# %%
df =df[df.lat!= 'N']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 343031 entries, 0 to 366637
# Data columns (total 18 columns):
# incident_number        343031 non-null object
# offense_code           343031 non-null int64
# offense_code_group     343031 non-null object
# offense_description    343031 non-null object
# district               343031 non-null object
# reporting_area         343031 non-null object
# shooting               343031 non-null object
# occurred_on_date       343031 non-null object
# year                   343031 non-null int64
# month                  343031 non-null int64
# day_of_week            343031 non-null object
# hour                   343031 non-null int64
# ucr_part               343031 non-null object
# street                 343031 non-null object
# lat                    343031 non-null object
# long                   343031 non-null object
# location               343031 non-null object
# District_Name          343031 non-null object
# ...

# %%
df =df[df.year==2019]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12855 entries, 0 to 282911
# Data columns (total 18 columns):
# incident_number        12855 non-null object
# offense_code           12855 non-null int64
# offense_code_group     12855 non-null object
# offense_description    12855 non-null object
# district               12855 non-null object
# reporting_area         12855 non-null object
# shooting               12855 non-null object
# occurred_on_date       12855 non-null object
# year                   12855 non-null int64
# month                  12855 non-null int64
# day_of_week            12855 non-null object
# hour                   12855 non-null int64
# ucr_part               12855 non-null object
# street                 12855 non-null object
# lat                    12855 non-null object
# long                   12855 non-null object
# location               12855 non-null object
# District_Name          12855 non-null object
# dtypes: int64(4), object(14)
# ...

# %%
df.district.value_counts()
# Out:
# B2     2052
# C11    1727
# D4     1599
# B3     1534
# A1     1424
# C6      903
# E18     822
# D14     745
# E13     672
# E5      569
# A7      508
# A15     255
# N        45
# Name: district, dtype: int64

# %%
df[df.district=='D14']
# Out:
#        incident_number  offense_code               offense_code_group  \
# 0           I192015748          3106          Property Related Damage
# 79          I192015646          3301                  Verbal Disputes
# 157         I192015552          3115               Investigate Person
# 162         I192015547          3802  Motor Vehicle Accident Response
# 180         I192015524          3115               Investigate Person
# 199         I192015506          3125                  Warrant Arrests
# 200         I192015506          3115               Investigate Person
# 206         I192015498          3115               Investigate Person
# 216         I192015489          3109         Police Service Incidents
# 217         I192015489          2900                            Other
# 233         I192015471          1102                            Fraud
# 239         I192015464          3803  Motor Vehicle Accident Response
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(df.district)

# %%
plt.hist(df)
